# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/employee_salary_dataset.csv")

# %%
df
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
df.head(4)
# Out:
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091

# %%
df.tail(5)
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 45          46  Employee_46          HR                 3             PhD
# 46          47  Employee_47     Finance                 3          Master
# 47          48  Employee_48  Operations                 1     High School
# 48          49  Employee_49     Finance                 5             PhD
# 49          50  Employee_50   Marketing                10     High School
#
#     Age  Gender       City  Monthly_Salary
# 45   54  Female  Hyderabad           88208
# 46   22  Female      Delhi           58828
# 47   40    Male    Chennai           43711
# 48   23  Female  Hyderabad           28420
# 49   47  Female  Bangalore          121752

# %%
df.describe()
# Out:
#        EmployeeID  Experience_Years        Age  Monthly_Salary
# count    50.00000         50.000000  50.000000         50.0000
# mean     25.50000          9.900000  39.760000      82288.8000
# std      14.57738          5.349995  11.539745      33521.4379
# min       1.00000          1.000000  22.000000      28420.0000
# 25%      13.25000          5.250000  28.250000      59424.0000
# 50%      25.50000         10.000000  43.500000      73890.5000
# 75%      37.75000         14.750000  49.000000     107219.0000
# max      50.00000         19.000000  57.000000     149123.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        50 non-null     int64
#  1   Name              50 non-null     object
#  2   Department        50 non-null     object
#  3   Experience_Years  50 non-null     int64
#  4   Education_Level   50 non-null     object
#  5   Age               50 non-null     int64
#  6   Gender            50 non-null     object
#  7   City              50 non-null     object
#  8   Monthly_Salary    50 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 3.6+ KB

# %%
df.shape
# Out:
# (50, 9)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Experience_Years',
#        'Education_Level', 'Age', 'Gender', 'City', 'Monthly_Salary'],
#       dtype='object')

# %%
df.isnull()
# Out:
#     EmployeeID   Name  Department  Experience_Years  Education_Level    Age  \
# 0        False  False       False             False            False  False
# 1        False  False       False             False            False  False
# 2        False  False       False             False            False  False
# 3        False  False       False             False            False  False
# 4        False  False       False             False            False  False
# 5        False  False       False             False            False  False
# 6        False  False       False             False            False  False
# 7        False  False       False             False            False  False
# 8        False  False       False             False            False  False
# 9        False  False       False             False            False  False
# 10       False  False       False             False            False  False
# ...

# %%
df.drop("Age",axis=1)
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
df.fillna(0)
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
df.sort_values("Monthly_Salary")
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 48          49  Employee_49     Finance                 5             PhD
# 13          14  Employee_14     Finance                 6        Bachelor
# 25          26  Employee_26          IT                14          Master
# 16          17  Employee_17   Marketing                18          Master
# 9           10  Employee_10  Operations                18     High School
# 8            9   Employee_9          IT                 4        Bachelor
# 38          39  Employee_39          HR                 1          Master
# 47          48  Employee_48  Operations                 1     High School
# 17          18  Employee_18  Operations                12             PhD
# 7            8   Employee_8          IT                17             PhD
# 18          19  Employee_19          HR                 2             PhD
# 44          45  Employee_45     Finance                 8          Master
# ...

# %%
df.groupby("Department")

# %%
df.loc[7]
# Out:
# EmployeeID                   8
# Name                Employee_8
# Department                  IT
# Experience_Years            17
# Education_Level            PhD
# Age                         34
# Gender                  Female
# City                 Bangalore
# Monthly_Salary           44830
# Name: 7, dtype: object

# %%
df.iloc[0:8]
# Out:
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
# 5           6  Employee_6     Finance                 3     High School   50
# 6           7  Employee_7          IT                14             PhD   57
# 7           8  Employee_8          IT                17             PhD   34
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091
# 4  Female      Delhi          132450
# 5    Male     Mumbai           65818
# ...

# %%
df["Monthly_Salary"].mean()
# Out:
# np.float64(82288.8)

# %%
df["Monthly_Salary"].sum()
# Out:
# np.int64(4114440)

# %%
df["Monthly_Salary"].max()
# Out:
# 149123

# %%
df["Monthly_Salary"].min()
# Out:
# 28420
